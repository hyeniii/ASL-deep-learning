# %% [markdown]
# # Script to generate masks for data in train and test
# # For EdgeConnect Inpainting

# %%
import os
import cv2
import numpy as np
from PIL import Image
import shutil

# %%
# define your paths
original_data_path = 'data'
new_data_path = 'new_data'  # this should be different from original_data_path
backup_data_path = 'data_backup'

# define function to generate random masks
def generate_random_mask(image_path, max_strokes=15):
    image = cv2.imread(image_path, 0)

    # Check if image was properly loaded
    if image is None:
        raise Exception(f'Image at path {image_path} could not be loaded.')

    # Initialize mask as all ones (i.e., white)
    mask = np.ones_like(image) * 255

    num_strokes = np.random.randint(5, max_strokes)
    height, width = image.shape

    for _ in range(num_strokes):
        x = np.random.randint(0, width)
        y = np.random.randint(0, height)
        end_x = np.random.randint(x, min(width, x+50))   # ensure stroke ends within image width
        end_y = np.random.randint(y, min(height, y+50)) # ensure stroke ends within image height
        color = 0  # black
        thickness = np.random.randint(10, 25)
        cv2.line(mask,(x,y),(end_x, end_y),color,thickness)
        
    return mask

# make a backup copy of the original data
shutil.copytree(original_data_path, backup_data_path)

try:
    # make necessary directories
    os.makedirs(os.path.join(new_data_path, 'original', 'train'), exist_ok=True)
    os.makedirs(os.path.join(new_data_path, 'original', 'test'), exist_ok=True)
    os.makedirs(os.path.join(new_data_path, 'mask', 'train'), exist_ok=True)
    os.makedirs(os.path.join(new_data_path, 'mask', 'test'), exist_ok=True)

    # move original images to new directories
    for split in ['train', 'test']:
        old_dir = os.path.join(original_data_path, split)
        new_dir = os.path.join(new_data_path, 'original', split)
    
        for filename in os.listdir(old_dir):
            shutil.move(os.path.join(old_dir, filename), new_dir)

    # create and save masks for train and test sets
    for split in ['train', 'test']:
        image_dir = os.path.join(new_data_path, 'original', split)
        mask_dir = os.path.join(new_data_path, 'mask', split)

        for img_name in os.listdir(image_dir):
            image_path = os.path.join(image_dir, img_name)

            # check that path is a file, not a directory
            if not os.path.isfile(image_path):
                print(f"Skipping {image_path} because it's not a file.")
                continue

            # check that file is an image (by extension)
            _, ext = os.path.splitext(img_name)
            if ext.lower() not in ['.png', '.jpg', '.jpeg']:
                print(f"Skipping {image_path} because it's not a recognized image file.")
                continue

            print(f"Processing image at path {image_path}")
            mask = generate_random_mask(image_path)

            mask_name = f"{os.path.splitext(img_name)[0]}_mask.png"
            cv2.imwrite(os.path.join(mask_dir, mask_name), mask)

except Exception as e:
    print(f"An error occurred: {e}")
    
    # restore original state in case of error
    if os.path.exists(original_data_path):
        shutil.rmtree(original_data_path)
    shutil.copytree(backup_data_path, original_data_path)
    shutil.rmtree(backup_data_path)
# Out:
# Processing image at path new_data/original/train/N2.jpg
# Processing image at path new_data/original/train/A27.jpg
# Processing image at path new_data/original/train/J33.jpg
# Processing image at path new_data/original/train/H8.jpg
# Processing image at path new_data/original/train/J19.jpg
# Processing image at path new_data/original/train/F6.jpg
# Processing image at path new_data/original/train/A17.jpg
# Processing image at path new_data/original/train/G6.jpg
# Processing image at path new_data/original/train/U22.jpg
# Processing image at path new_data/original/train/G26.jpg
# Processing image at path new_data/original/train/Q2.jpg
# Processing image at path new_data/original/train/N3.jpg
# Processing image at path new_data/original/train/S11.jpg
# Processing image at path new_data/original/train/M17.jpg
# Processing image at path new_data/original/train/K10.jpg
# Processing image at path new_data/original/train/R11.jpg
# Processing image at path new_data/original/train/S24.jpg
# Processing image at path new_data/original/train/H22.jpg
# Processing image at path new_data/original/train/X6.jpg
# Processing image at path new_data/original/train/Y24.jpg
# Processing image at path new_data/original/train/K17.jpg
# Processing image at path new_data/original/train/W15.jpg
# Processing image at path new_data/original/train/V9.jpg
# Processing image at path new_data/original/train/R13.jpg
# Processing image at path new_data/original/train/L16.jpg
# Processing image at path new_data/original/train/L9.jpg
# Processing image at path new_data/original/train/R3.jpg
# Processing image at path new_data/original/train/V15.jpg
# Processing image at path new_data/original/train/L20.jpg
# Processing image at path new_data/original/train/F9.jpg
# Processing image at path new_data/original/train/M3.jpg
# Processing image at path new_data/original/train/Z25.jpg
# Processing image at path new_data/original/train/M18.jpg
# Processing image at path new_data/original/train/O7.jpg
# Processing image at path new_data/original/train/F15.jpg
# Processing image at path new_data/original/train/A21.jpg
# Processing image at path new_data/original/train/K7.jpg
# Processing image at path new_data/original/train/J29.jpg
# Processing image at path new_data/original/train/A15.jpg
# Processing image at path new_data/original/train/X17.jpg
# Processing image at path new_data/original/train/I6.jpg
# Processing image at path new_data/original/train/P22.jpg
# Processing image at path new_data/original/train/W0.jpg
# Processing image at path new_data/original/train/Y18.jpg
# Processing image at path new_data/original/train/G17.jpg
# Processing image at path new_data/original/train/P14.jpg
# Processing image at path new_data/original/train/S8.jpg
# Processing image at path new_data/original/train/D19.jpg
# Processing image at path new_data/original/train/I23.jpg
# Processing image at path new_data/original/train/L17.jpg
# Processing image at path new_data/original/train/D9.jpg
# Processing image at path new_data/original/train/A4.jpg
# Processing image at path new_data/original/train/J36.jpg
# Processing image at path new_data/original/train/R16.jpg
# Processing image at path new_data/original/train/Z3.jpg
# Processing image at path new_data/original/train/X0.jpg
# Processing image at path new_data/original/train/S1.jpg
# Processing image at path new_data/original/train/U19.jpg
# Processing image at path new_data/original/train/B13.jpg
# Processing image at path new_data/original/train/V18.jpg
# Processing image at path new_data/original/train/L13.jpg
# Processing image at path new_data/original/train/Y6.jpg
# Processing image at path new_data/original/train/B24.jpg
# Processing image at path new_data/original/train/T15.jpg
# Processing image at path new_data/original/train/X21.jpg
# Processing image at path new_data/original/train/J25.jpg
# Processing image at path new_data/original/train/R4.jpg
# Processing image at path new_data/original/train/G22.jpg
# Processing image at path new_data/original/train/L22.jpg
# Processing image at path new_data/original/train/L10.jpg
# Processing image at path new_data/original/train/O6.jpg
# Processing image at path new_data/original/train/K21.jpg
# Processing image at path new_data/original/train/X10.jpg
# Processing image at path new_data/original/train/E24.jpg
# Processing image at path new_data/original/train/G25.jpg
# Processing image at path new_data/original/train/W6.jpg
# Processing image at path new_data/original/train/T21.jpg
# Processing image at path new_data/original/train/C11.jpg
# Processing image at path new_data/original/train/C2.jpg
# Processing image at path new_data/original/train/E15.jpg
# Processing image at path new_data/original/train/U14.jpg
# Processing image at path new_data/original/train/O10.jpg
# Processing image at path new_data/original/train/Z26.jpg
# Processing image at path new_data/original/train/Q1.jpg
# Processing image at path new_data/original/train/G8.jpg
# Processing image at path new_data/original/train/D18.jpg
# Processing image at path new_data/original/train/R19.jpg
# Processing image at path new_data/original/train/Z10.jpg
# Processing image at path new_data/original/train/A28.jpg
# Processing image at path new_data/original/train/S15.jpg
# Processing image at path new_data/original/train/S12.jpg
# Processing image at path new_data/original/train/L18.jpg
# Processing image at path new_data/original/train/F26.jpg
# Processing image at path new_data/original/train/B17.jpg
# Processing image at path new_data/original/train/T10.jpg
# Processing image at path new_data/original/train/T14.jpg
# Processing image at path new_data/original/train/B7.jpg
# Processing image at path new_data/original/train/B20.jpg
# Processing image at path new_data/original/train/F22.jpg
# Processing image at path new_data/original/train/Q5.jpg
# Processing image at path new_data/original/train/O25.jpg
# Processing image at path new_data/original/train/W13.jpg
# Processing image at path new_data/original/train/F12.jpg
# Processing image at path new_data/original/train/P0.jpg
# Processing image at path new_data/original/train/G28.jpg
# Processing image at path new_data/original/train/E3.jpg
# Processing image at path new_data/original/train/G10.jpg
# Processing image at path new_data/original/train/Q3.jpg
# Processing image at path new_data/original/train/Y3.jpg
# Processing image at path new_data/original/train/U0.jpg
# Processing image at path new_data/original/train/G15.jpg
# Processing image at path new_data/original/train/C5.jpg
# Processing image at path new_data/original/train/E21.jpg
# Processing image at path new_data/original/train/Q16.jpg
# Processing image at path new_data/original/train/O16.jpg
# Processing image at path new_data/original/train/R23.jpg
# Processing image at path new_data/original/train/A19.jpg
# Processing image at path new_data/original/train/G2.jpg
# Processing image at path new_data/original/train/D16.jpg
# Processing image at path new_data/original/train/A12.jpg
# Processing image at path new_data/original/train/A25.jpg
# Processing image at path new_data/original/train/D24.jpg
# Processing image at path new_data/original/train/C0.jpg
# Processing image at path new_data/original/train/Q0.jpg
# Processing image at path new_data/original/train/G14.jpg
# Processing image at path new_data/original/train/I11.jpg
# Processing image at path new_data/original/train/H4.jpg
# Processing image at path new_data/original/train/F1.jpg
# Processing image at path new_data/original/train/S3.jpg
# Processing image at path new_data/original/train/Q24.jpg
# Processing image at path new_data/original/train/E13.jpg
# Processing image at path new_data/original/train/K22.jpg
# Processing image at path new_data/original/train/S9.jpg
# Processing image at path new_data/original/train/I29.jpg
# Processing image at path new_data/original/train/V1.jpg
# Processing image at path new_data/original/train/V4.jpg
# Processing image at path new_data/original/train/I16.jpg
# Processing image at path new_data/original/train/B4.jpg
# Processing image at path new_data/original/train/H7.jpg
# Processing image at path new_data/original/train/Q12.jpg
# Processing image at path new_data/original/train/H23.jpg
# Processing image at path new_data/original/train/B18.jpg
# Processing image at path new_data/original/train/C18.jpg
# Processing image at path new_data/original/train/D10.jpg
# Processing image at path new_data/original/train/E20.jpg
# Processing image at path new_data/original/train/O14.jpg
# Processing image at path new_data/original/train/F10.jpg
# Processing image at path new_data/original/train/N23.jpg
# Processing image at path new_data/original/train/F23.jpg
# Processing image at path new_data/original/train/O2.jpg
# Processing image at path new_data/original/train/S19.jpg
# Processing image at path new_data/original/train/A5.jpg
# Processing image at path new_data/original/train/D21.jpg
# Processing image at path new_data/original/train/M11.jpg
# Processing image at path new_data/original/train/Y2.jpg
# Processing image at path new_data/original/train/P12.jpg
# Processing image at path new_data/original/train/V14.jpg
# Processing image at path new_data/original/train/I3.jpg
# Processing image at path new_data/original/train/V5.jpg
# Processing image at path new_data/original/train/I25.jpg
# Processing image at path new_data/original/train/M8.jpg
# Processing image at path new_data/original/train/Z23.jpg
# Processing image at path new_data/original/train/W18.jpg
# Processing image at path new_data/original/train/J37.jpg
# Processing image at path new_data/original/train/Z19.jpg
# Processing image at path new_data/original/train/F24.jpg
# Processing image at path new_data/original/train/P15.jpg
# Processing image at path new_data/original/train/M4.jpg
# Processing image at path new_data/original/train/A2.jpg
# Processing image at path new_data/original/train/N11.jpg
# Processing image at path new_data/original/train/I26.jpg
# Processing image at path new_data/original/train/D6.jpg
# Processing image at path new_data/original/train/O9.jpg
# Processing image at path new_data/original/train/V6.jpg
# Processing image at path new_data/original/train/U11.jpg
# Processing image at path new_data/original/train/H11.jpg
# Processing image at path new_data/original/train/W8.jpg
# Processing image at path new_data/original/train/Z21.jpg
# Processing image at path new_data/original/train/Q15.jpg
# Processing image at path new_data/original/train/F21.jpg
# Processing image at path new_data/original/train/I5.jpg
# Processing image at path new_data/original/train/X23.jpg
# Processing image at path new_data/original/train/V22.jpg
# Processing image at path new_data/original/train/W5.jpg
# Processing image at path new_data/original/train/Y22.jpg
# Processing image at path new_data/original/train/S29.jpg
# Processing image at path new_data/original/train/X5.jpg
# Processing image at path new_data/original/train/C13.jpg
# Processing image at path new_data/original/train/K25.jpg
# Processing image at path new_data/original/train/H16.jpg
# Processing image at path new_data/original/train/D8.jpg
# Processing image at path new_data/original/train/F2.jpg
# Processing image at path new_data/original/train/X15.jpg
# Processing image at path new_data/original/train/N19.jpg
# Processing image at path new_data/original/train/I8.jpg
# Processing image at path new_data/original/train/V24.jpg
# Processing image at path new_data/original/train/F25.jpg
# Processing image at path new_data/original/train/Z13.jpg
# Processing image at path new_data/original/train/E19.jpg
# Processing image at path new_data/original/train/E1.jpg
# Processing image at path new_data/original/train/S13.jpg
# Processing image at path new_data/original/train/Z12.jpg
# Processing image at path new_data/original/train/Q14.jpg
# Processing image at path new_data/original/train/X25.jpg
# Processing image at path new_data/original/train/J32.jpg
# Processing image at path new_data/original/train/G12.jpg
# Processing image at path new_data/original/train/H6.jpg
# Processing image at path new_data/original/train/L12.jpg
# Processing image at path new_data/original/train/T7.jpg
# Processing image at path new_data/original/train/U16.jpg
# Processing image at path new_data/original/train/O21.jpg
# Processing image at path new_data/original/train/X1.jpg
# Processing image at path new_data/original/train/I0.jpg
# Processing image at path new_data/original/train/H9.jpg
# Processing image at path new_data/original/train/Z7.jpg
# Processing image at path new_data/original/train/C10.jpg
# Processing image at path new_data/original/train/W12.jpg
# Processing image at path new_data/original/train/K18.jpg
# Processing image at path new_data/original/train/E9.jpg
# Processing image at path new_data/original/train/N4.jpg
# Processing image at path new_data/original/train/E0.jpg
# Processing image at path new_data/original/train/I14.jpg
# Processing image at path new_data/original/train/J34.jpg
# Processing image at path new_data/original/train/J30.jpg
# Processing image at path new_data/original/train/Q17.jpg
# Processing image at path new_data/original/train/D26.jpg
# Processing image at path new_data/original/train/B2.jpg
# Processing image at path new_data/original/train/U1.jpg
# Processing image at path new_data/original/train/S20.jpg
# Processing image at path new_data/original/train/T19.jpg
# Processing image at path new_data/original/train/Y14.jpg
# Processing image at path new_data/original/train/N10.jpg
# Processing image at path new_data/original/train/P19.jpg
# Processing image at path new_data/original/train/K16.jpg
# Processing image at path new_data/original/train/C14.jpg
# Processing image at path new_data/original/train/W4.jpg
# Processing image at path new_data/original/train/A11.jpg
# Processing image at path new_data/original/train/F18.jpg
# Processing image at path new_data/original/train/W21.jpg
# Processing image at path new_data/original/train/X11.jpg
# Processing image at path new_data/original/train/Q25.jpg
# Processing image at path new_data/original/train/J21.jpg
# Processing image at path new_data/original/train/G1.jpg
# Processing image at path new_data/original/train/B8.jpg
# Processing image at path new_data/original/train/O19.jpg
# Processing image at path new_data/original/train/E8.jpg
# Processing image at path new_data/original/train/Y15.jpg
# Processing image at path new_data/original/train/O24.jpg
# Processing image at path new_data/original/train/G27.jpg
# Processing image at path new_data/original/train/D23.jpg
# Processing image at path new_data/original/train/J31.jpg
# Processing image at path new_data/original/train/A1.jpg
# Processing image at path new_data/original/train/N7.jpg
# Processing image at path new_data/original/train/C8.jpg
# Processing image at path new_data/original/train/Z5.jpg
# Processing image at path new_data/original/train/V19.jpg
# Processing image at path new_data/original/train/I24.jpg
# Processing image at path new_data/original/train/S17.jpg
# Processing image at path new_data/original/train/A7.jpg
# Processing image at path new_data/original/train/M22.jpg
# Processing image at path new_data/original/train/K4.jpg
# Processing image at path new_data/original/train/F27.jpg
# Processing image at path new_data/original/train/L1.jpg
# Processing image at path new_data/original/train/F7.jpg
# Processing image at path new_data/original/train/U13.jpg
# Processing image at path new_data/original/train/O23.jpg
# Processing image at path new_data/original/train/G13.jpg
# Processing image at path new_data/original/train/Q18.jpg
# Processing image at path new_data/original/train/X22.jpg
# Processing image at path new_data/original/train/S28.jpg
# Processing image at path new_data/original/train/J18.jpg
# Processing image at path new_data/original/train/S25.jpg
# Processing image at path new_data/original/train/L5.jpg
# Processing image at path new_data/original/train/K26.jpg
# Processing image at path new_data/original/train/I18.jpg
# Processing image at path new_data/original/train/L8.jpg
# Processing image at path new_data/original/train/E10.jpg
# Processing image at path new_data/original/train/H10.jpg
# Processing image at path new_data/original/train/E2.jpg
# Processing image at path new_data/original/train/K11.jpg
# Processing image at path new_data/original/train/W14.jpg
# Processing image at path new_data/original/train/O5.jpg
# Processing image at path new_data/original/train/S21.jpg
# Processing image at path new_data/original/train/R9.jpg
# Processing image at path new_data/original/train/X2.jpg
# Processing image at path new_data/original/train/A0.jpg
# Processing image at path new_data/original/train/U23.jpg
# Processing image at path new_data/original/train/B3.jpg
# Processing image at path new_data/original/train/E14.jpg
# Processing image at path new_data/original/train/C6.jpg
# Processing image at path new_data/original/train/U20.jpg
# Processing image at path new_data/original/train/H17.jpg
# Processing image at path new_data/original/train/S14.jpg
# Processing image at path new_data/original/train/I1.jpg
# Processing image at path new_data/original/train/F14.jpg
# Processing image at path new_data/original/train/F28.jpg
# Processing image at path new_data/original/train/H12.jpg
# Processing image at path new_data/original/train/X3.jpg
# Processing image at path new_data/original/train/M19.jpg
# Processing image at path new_data/original/train/X13.jpg
# Processing image at path new_data/original/train/D3.jpg
# Processing image at path new_data/original/train/W1.jpg
# Processing image at path new_data/original/train/Z8.jpg
# Processing image at path new_data/original/train/E5.jpg
# Processing image at path new_data/original/train/Q19.jpg
# Processing image at path new_data/original/train/S10.jpg
# Processing image at path new_data/original/train/W17.jpg
# Processing image at path new_data/original/train/J23.jpg
# Processing image at path new_data/original/train/P6.jpg
# Processing image at path new_data/original/train/A8.jpg
# Processing image at path new_data/original/train/I15.jpg
# Processing image at path new_data/original/train/Q4.jpg
# Processing image at path new_data/original/train/X4.jpg
# Processing image at path new_data/original/train/K3.jpg
# Processing image at path new_data/original/train/H24.jpg
# Processing image at path new_data/original/train/J35.jpg
# Processing image at path new_data/original/train/D22.jpg
# Processing image at path new_data/original/train/X16.jpg
# Processing image at path new_data/original/train/R12.jpg
# Processing image at path new_data/original/train/N24.jpg
# Processing image at path new_data/original/train/P3.jpg
# Processing image at path new_data/original/train/X7.jpg
# Processing image at path new_data/original/train/E22.jpg
# Processing image at path new_data/original/train/Z15.jpg
# Processing image at path new_data/original/train/A18.jpg
# Processing image at path new_data/original/train/P5.jpg
# Processing image at path new_data/original/train/C20.jpg
# Processing image at path new_data/original/train/R14.jpg
# Processing image at path new_data/original/train/T0.jpg
# Processing image at path new_data/original/train/Y1.jpg
# Processing image at path new_data/original/train/N0.jpg
# Processing image at path new_data/original/train/C21.jpg
# Processing image at path new_data/original/train/C4.jpg
# Processing image at path new_data/original/train/P10.jpg
# Processing image at path new_data/original/train/F20.jpg
# Processing image at path new_data/original/train/Q21.jpg
# Processing image at path new_data/original/train/D27.jpg
# Processing image at path new_data/original/train/Y12.jpg
# Processing image at path new_data/original/train/L15.jpg
# Processing image at path new_data/original/train/R10.jpg
# Processing image at path new_data/original/train/P11.jpg
# Processing image at path new_data/original/train/A26.jpg
# Processing image at path new_data/original/train/L7.jpg
# Processing image at path new_data/original/train/Z14.jpg
# Processing image at path new_data/original/train/J20.jpg
# Processing image at path new_data/original/train/Z17.jpg
# Processing image at path new_data/original/train/O27.jpg
# Processing image at path new_data/original/train/L23.jpg
# Processing image at path new_data/original/train/W2.jpg
# Processing image at path new_data/original/train/J0.jpg
# Processing image at path new_data/original/train/G19.jpg
# Processing image at path new_data/original/train/P7.jpg
# Processing image at path new_data/original/train/G16.jpg
# Processing image at path new_data/original/train/L21.jpg
# Processing image at path new_data/original/train/A16.jpg
# Processing image at path new_data/original/train/L4.jpg
# Processing image at path new_data/original/train/V20.jpg
# Processing image at path new_data/original/train/D11.jpg
# Processing image at path new_data/original/train/L19.jpg
# Processing image at path new_data/original/train/M27.jpg
# Processing image at path new_data/original/train/C3.jpg
# Processing image at path new_data/original/train/W10.jpg
# Processing image at path new_data/original/train/U17.jpg
# Processing image at path new_data/original/train/I27.jpg
# Processing image at path new_data/original/train/O26.jpg
# Processing image at path new_data/original/train/Q13.jpg
# Processing image at path new_data/original/train/H28.jpg
# Processing image at path new_data/original/train/Z6.jpg
# Processing image at path new_data/original/train/I21.jpg
# Processing image at path new_data/original/train/E17.jpg
# Processing image at path new_data/original/train/N21.jpg
# Processing image at path new_data/original/train/K14.jpg
# Processing image at path new_data/original/train/T3.jpg
# Processing image at path new_data/original/train/N25.jpg
# Processing image at path new_data/original/train/Z0.jpg
# Processing image at path new_data/original/train/T20.jpg
# Processing image at path new_data/original/train/R2.jpg
# Processing image at path new_data/original/train/V16.jpg
# Processing image at path new_data/original/train/D25.jpg
# Processing image at path new_data/original/train/L3.jpg
# Processing image at path new_data/original/train/N12.jpg
# Processing image at path new_data/original/train/I22.jpg
# Processing image at path new_data/original/train/Z29.jpg
# Processing image at path new_data/original/train/T6.jpg
# Processing image at path new_data/original/train/M21.jpg
# Processing image at path new_data/original/train/K15.jpg
# Processing image at path new_data/original/train/Q23.jpg
# Processing image at path new_data/original/train/T23.jpg
# Processing image at path new_data/original/train/G0.jpg
# Processing image at path new_data/original/train/T22.jpg
# Processing image at path new_data/original/train/J7.jpg
# Processing image at path new_data/original/train/J1.jpg
# Processing image at path new_data/original/train/H2.jpg
# Processing image at path new_data/original/train/Y11.jpg
# Processing image at path new_data/original/train/P20.jpg
# Processing image at path new_data/original/train/I2.jpg
# Processing image at path new_data/original/train/K19.jpg
# Processing image at path new_data/original/train/B11.jpg
# Processing image at path new_data/original/train/A6.jpg
# Processing image at path new_data/original/train/M1.jpg
# Processing image at path new_data/original/train/J3.jpg
# Skipping new_data/original/train/.ipynb_checkpoints because it's not a file.
# Processing image at path new_data/original/train/C16.jpg
# Processing image at path new_data/original/train/E23.jpg
# Processing image at path new_data/original/train/Z28.jpg
# Processing image at path new_data/original/train/Z24.jpg
# Processing image at path new_data/original/train/U7.jpg
# Processing image at path new_data/original/train/Q11.jpg
# Processing image at path new_data/original/train/K2.jpg
# Processing image at path new_data/original/train/W3.jpg
# Processing image at path new_data/original/train/G29.jpg
# Processing image at path new_data/original/train/I4.jpg
# Processing image at path new_data/original/train/N20.jpg
# Processing image at path new_data/original/train/M23.jpg
# Processing image at path new_data/original/train/R24.jpg
# Processing image at path new_data/original/train/V7.jpg
# Processing image at path new_data/original/train/B22.jpg
# Processing image at path new_data/original/train/E6.jpg
# Processing image at path new_data/original/train/S5.jpg
# Processing image at path new_data/original/train/V26.jpg
# Processing image at path new_data/original/train/J17.jpg
# Processing image at path new_data/original/train/O18.jpg
# Processing image at path new_data/original/train/H20.jpg
# Processing image at path new_data/original/train/Q6.jpg
# Processing image at path new_data/original/train/U8.jpg
# Processing image at path new_data/original/train/S26.jpg
# Processing image at path new_data/original/train/R7.jpg
# Processing image at path new_data/original/train/M0.jpg
# Processing image at path new_data/original/train/A13.jpg
# Processing image at path new_data/original/train/O1.jpg
# Processing image at path new_data/original/train/D2.jpg
# Processing image at path new_data/original/train/M16.jpg
# Processing image at path new_data/original/train/P13.jpg
# Processing image at path new_data/original/train/S18.jpg
# Processing image at path new_data/original/train/X18.jpg
# Processing image at path new_data/original/train/D4.jpg
# Processing image at path new_data/original/train/H26.jpg
# Processing image at path new_data/original/train/T5.jpg
# Processing image at path new_data/original/train/Y8.jpg
# Processing image at path new_data/original/train/I20.jpg
# Processing image at path new_data/original/train/M13.jpg
# Processing image at path new_data/original/train/M2.jpg
# Processing image at path new_data/original/train/C24.jpg
# Processing image at path new_data/original/train/R22.jpg
# Processing image at path new_data/original/train/N17.jpg
# Processing image at path new_data/original/train/V23.jpg
# Processing image at path new_data/original/train/C7.jpg
# Processing image at path new_data/original/train/I12.jpg
# Processing image at path new_data/original/train/W9.jpg
# Processing image at path new_data/original/train/P21.jpg
# Processing image at path new_data/original/train/J22.jpg
# Processing image at path new_data/original/train/Y4.jpg
# Processing image at path new_data/original/train/N5.jpg
# Processing image at path new_data/original/train/J10.jpg
# Processing image at path new_data/original/train/V17.jpg
# Processing image at path new_data/original/train/R1.jpg
# Processing image at path new_data/original/train/Z1.jpg
# Processing image at path new_data/original/train/P16.jpg
# Processing image at path new_data/original/train/U4.jpg
# Processing image at path new_data/original/train/V8.jpg
# Processing image at path new_data/original/train/X19.jpg
# Processing image at path new_data/original/train/E11.jpg
# Processing image at path new_data/original/train/I9.jpg
# Processing image at path new_data/original/train/J2.jpg
# Processing image at path new_data/original/train/J15.jpg
# Processing image at path new_data/original/train/I7.jpg
# Processing image at path new_data/original/train/Y19.jpg
# Processing image at path new_data/original/train/U12.jpg
# Processing image at path new_data/original/train/N14.jpg
# Processing image at path new_data/original/train/F16.jpg
# Processing image at path new_data/original/train/N8.jpg
# Processing image at path new_data/original/train/G24.jpg
# Processing image at path new_data/original/train/P4.jpg
# Processing image at path new_data/original/train/L2.jpg
# Processing image at path new_data/original/train/N13.jpg
# Processing image at path new_data/original/train/X8.jpg
# Processing image at path new_data/original/train/L24.jpg
# Processing image at path new_data/original/train/Y9.jpg
# Processing image at path new_data/original/train/L25.jpg
# Processing image at path new_data/original/train/A24.jpg
# Processing image at path new_data/original/train/Y16.jpg
# Processing image at path new_data/original/train/W11.jpg
# Processing image at path new_data/original/train/L0.jpg
# Processing image at path new_data/original/train/D5.jpg
# Processing image at path new_data/original/train/I10.jpg
# Processing image at path new_data/original/train/L6.jpg
# Processing image at path new_data/original/train/V13.jpg
# Processing image at path new_data/original/train/U10.jpg
# Processing image at path new_data/original/train/Z20.jpg
# Processing image at path new_data/original/train/J13.jpg
# Processing image at path new_data/original/train/D14.jpg
# Processing image at path new_data/original/train/J11.jpg
# Processing image at path new_data/original/train/T9.jpg
# Processing image at path new_data/original/train/N26.jpg
# Processing image at path new_data/original/train/O15.jpg
# Processing image at path new_data/original/train/W20.jpg
# Processing image at path new_data/original/train/S7.jpg
# Processing image at path new_data/original/train/M15.jpg
# Processing image at path new_data/original/train/S23.jpg
# Processing image at path new_data/original/train/D13.jpg
# Processing image at path new_data/original/train/K8.jpg
# Processing image at path new_data/original/train/B16.jpg
# Processing image at path new_data/original/train/C12.jpg
# Processing image at path new_data/original/train/E12.jpg
# Processing image at path new_data/original/train/A23.jpg
# Processing image at path new_data/original/test/B19.jpg
# Processing image at path new_data/original/test/F17.jpg
# Processing image at path new_data/original/test/T13.jpg
# Processing image at path new_data/original/test/G11.jpg
# Processing image at path new_data/original/test/U6.jpg
# Processing image at path new_data/original/test/V12.jpg
# Processing image at path new_data/original/test/K13.jpg
# Processing image at path new_data/original/test/J6.jpg
# Processing image at path new_data/original/test/J27.jpg
# Processing image at path new_data/original/test/G4.jpg
# Processing image at path new_data/original/test/K6.jpg
# Processing image at path new_data/original/test/X14.jpg
# Processing image at path new_data/original/test/B14.jpg
# Processing image at path new_data/original/test/S0.jpg
# Processing image at path new_data/original/test/H19.jpg
# Processing image at path new_data/original/test/X20.jpg
# Processing image at path new_data/original/test/C19.jpg
# Processing image at path new_data/original/test/Y5.jpg
# Processing image at path new_data/original/test/C22.jpg
# Processing image at path new_data/original/test/C17.jpg
# Processing image at path new_data/original/test/O20.jpg
# Processing image at path new_data/original/test/T18.jpg
# Processing image at path new_data/original/test/W16.jpg
# Processing image at path new_data/original/test/Z18.jpg
# Processing image at path new_data/original/test/B15.jpg
# Processing image at path new_data/original/test/J28.jpg
# Processing image at path new_data/original/test/M14.jpg
# Processing image at path new_data/original/test/N9.jpg
# Processing image at path new_data/original/test/O12.jpg
# Processing image at path new_data/original/test/X24.jpg
# Processing image at path new_data/original/test/N22.jpg
# Processing image at path new_data/original/test/G3.jpg
# Processing image at path new_data/original/test/H5.jpg
# Processing image at path new_data/original/test/X9.jpg
# Processing image at path new_data/original/test/G20.jpg
# Processing image at path new_data/original/test/T24.jpg
# Processing image at path new_data/original/test/M20.jpg
# Processing image at path new_data/original/test/J9.jpg
# Processing image at path new_data/original/test/S16.jpg
# Processing image at path new_data/original/test/R18.jpg
# Processing image at path new_data/original/test/C23.jpg
# Processing image at path new_data/original/test/P24.jpg
# Processing image at path new_data/original/test/Y25.jpg
# Processing image at path new_data/original/test/R5.jpg
# Processing image at path new_data/original/test/O4.jpg
# Processing image at path new_data/original/test/I28.jpg
# Processing image at path new_data/original/test/Q7.jpg
# Processing image at path new_data/original/test/Z16.jpg
# Processing image at path new_data/original/test/T17.jpg
# Processing image at path new_data/original/test/U5.jpg
# Processing image at path new_data/original/test/W19.jpg
# Processing image at path new_data/original/test/W7.jpg
# Processing image at path new_data/original/test/V10.jpg
# Skipping new_data/original/test/.ipynb_checkpoints because it's not a file.
# Processing image at path new_data/original/test/I17.jpg
# Processing image at path new_data/original/test/H25.jpg
# Processing image at path new_data/original/test/M24.jpg
# Processing image at path new_data/original/test/S6.jpg
# Processing image at path new_data/original/test/V2.jpg
# Processing image at path new_data/original/test/Z9.jpg
# Processing image at path new_data/original/test/W24.jpg
# Processing image at path new_data/original/test/Z27.jpg
# Processing image at path new_data/original/test/W23.jpg
# Processing image at path new_data/original/test/V27.jpg
# Processing image at path new_data/original/test/N6.jpg
# Processing image at path new_data/original/test/T1.jpg
# Processing image at path new_data/original/test/Q10.jpg
# Processing image at path new_data/original/test/K24.jpg
# Processing image at path new_data/original/test/G7.jpg
# Processing image at path new_data/original/test/A22.jpg
# Processing image at path new_data/original/test/D1.jpg
# Processing image at path new_data/original/test/K12.jpg
# Processing image at path new_data/original/test/F3.jpg
