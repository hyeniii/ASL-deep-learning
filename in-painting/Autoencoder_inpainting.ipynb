# %%
#from google.colab import drive
#drive.mount('/content/drive',force_remount=True)

# %% [markdown]
# # Autoencoder inpainting
# Made with assistance from https://wandb.ai/site/articles/introduction-to-image-inpainting-with-deep-learning

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import os
import cv2
import numpy as np
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pickle
# Out:
# 2023-05-29 07:09:52.156804: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load Data

# %%
#image_directory = '/content/drive/MyDrive/Grad School/ASL-Data/data/train/matching_images'
image_directory = './data/train/matching_images'

# Get the list of image file names
image_files = os.listdir(image_directory)

# Load the images and assign labels manually
x_train = []
y_train = []

for filename in image_files:
    # Load the image
    image_path = os.path.join(image_directory, filename)
    image = keras.preprocessing.image.load_img(image_path, target_size=(256, 256))
    image_array = keras.preprocessing.image.img_to_array(image).astype('uint8')  # Convert to uint8
    
    # Add the image to the training data
    x_train.append(image_array)
    
    # Assign a label based on the filename or any other criteria
    # Modify this part according to your labeling requirements
    y_train.append(filename[0])

# Convert the lists to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (504, 256, 256, 3)
# 504 train samples
# y_train shape: (504,)

# %%
x_train = np.concatenate([x_train, x_train, x_train, x_train], axis=0)
y_train = np.concatenate([y_train, y_train, y_train,y_train], axis=0)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (2016, 256, 256, 3)
# 2016 train samples
# y_train shape: (2016,)

# %%
#image_directory = '/content/drive/MyDrive/Grad School/ASL-Data/data/test/matching_images'
image_directory = './data/test/matching_images'

# Get the list of image file names
image_files = os.listdir(image_directory)

# Load the images and assign labels manually
x_test = []
y_test = []

for filename in image_files:
    # Load the image
    image_path = os.path.join(image_directory, filename)
    image = keras.preprocessing.image.load_img(image_path, target_size=(256, 256))
    image_array = keras.preprocessing.image.img_to_array(image).astype('uint8')  # Convert to uint8
    
    # Add the image to the training data
    x_test.append(image_array)
    
    # Assign a label based on the filename or any other criteria
    # Modify this part according to your labeling requirements
    y_test.append(filename[0])

# Convert the lists to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

print('x_test shape:', x_test.shape)
print(x_test.shape[0], 'test samples')
print('y_test shape:', y_test.shape)
# Out:
# x_test shape: (72, 256, 256, 3)
# 72 test samples
# y_test shape: (72,)

# %% [markdown]
# ## Create Data Generators for Batch Training

# %%
## Ref: https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.
class createAugment(keras.utils.Sequence):
  #'Generates data for Keras'
    def __init__(self, X, y, batch_size=32, dim=(256, 256), n_channels=3, shuffle=True):
        #'Initialization'
        self.batch_size = batch_size 
        self.X = X 
        self.y = y
        self.dim = dim
        self.n_channels = n_channels
        self.shuffle = shuffle

        self.on_epoch_end()

    def __len__(self):
        #'Denotes the number of batches per epoch'
        return int(np.floor(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Generate data
        return self.__data_generation(indexes)

    def on_epoch_end(self):
        #'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.X))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, idxs):
        # X_batch is a matrix of masked images used as input
        X_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Masked image
        # y_batch is a matrix of original images used for computing error from reconstructed image
        y_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Original image

        ## Iterate through random indexes
        for i, idx in enumerate(idxs):
            image_copy = self.X[idx].copy()

            ## Get mask associated to that image
            masked_image = self.__createMask(image_copy)

            X_batch[i,] = masked_image/255
            y_batch[i] = self.y[idx]/255

        return X_batch, y_batch

    def __createMask(self, img):
        ## Prepare masking matrix
        mask = np.full((256,256,3), 255, np.uint8)
        for _ in range(np.random.randint(1, 10)):
            # Get random x locations to start line
            x1, x2 = np.random.randint(1, 256), np.random.randint(1, 256)
            # Get random y locations to start line
            y1, y2 = np.random.randint(1, 256), np.random.randint(1, 256)
            # Get random thickness of the line drawn
            thickness = np.random.randint(8, 16)
            # Draw black line on the white mask
            cv2.line(mask,(x1,y1),(x2,y2),(1,1,1),thickness)

        # Perforn bitwise and operation to mak the image
        masked_image = cv2.bitwise_and(img, mask)

        return masked_image

# %%
## Prepare training and testing mask-image pair generator
traingen = createAugment(x_train, x_train)
testgen = createAugment(x_test, x_test, shuffle=False)

# %% [markdown]
# ## Display Corrupted and Uncorrupted Images

# %%
## Examples
sample_idx = 2 ## Change this to see different batches

sample_masks, sample_labels = traingen[sample_idx]
sample_images = [None]*(len(sample_masks)+len(sample_labels))
sample_images[::2] = sample_labels
sample_images[1::2] = sample_masks

fig = plt.figure(figsize=(16., 8.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 8),  # creates 2x2 grid of axes
                 axes_pad=0.3,  # pad between axes in inch.
                 )

for ax, image in zip(grid, sample_images):
    ax.imshow(image)

plt.show()

# %% [markdown]
# ## Define Metric for Model Evaluation
# Dice coefficient is a metric commonly used to evaluate the accuracy and quality of the predicted masks compared to the ground truth masks. A higher Dice coefficient indicates better similarity and overlap between the predicted and ground truth masks, indicating better performance.
#
# The Dice coefficient is calculated as follows: Dice_coef = (2 * |A ∩ B|) / (|A| + |B|)
# - |A ∩ B| represents the intersection of images A and B, i.e., the number of common pixels between the two images.
# - |A| represents the number pixels in image A.
# - |B| represents the number pixels in image B.

# %%
## For more information into formulation: https://www.youtube.com/watch?v=AZr64OxshLo
## Metric
def dice_coef(y_true, y_pred):
    y_true_f = keras.backend.flatten(y_true)
    y_pred_f = keras.backend.flatten(y_pred)
    intersection = keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (keras.backend.sum(y_true_f + y_pred_f))

# %% [markdown]
# ## Define Model Architecture
# The structure is based on a UNET-like model and is an autoencoder(source)
# - Four downsample blocks and four upsample blocks.
# - Each downsample block consists of two consecutive convolutional layers and a max pooling layer.
# - Each upsample block consists of two consecutive convolutional layers and a transposed convolutional layer. The upsampled feature maps are concatenated with the corresponding feature maps from the downsample path (shared_layer) along the channel axis.
# - The final upsample block does not have a pooling layer after the convolutional layers.
# - The model ends with a 2D convolutional layer with 3 filters (for RGB channels) and sigmoid activation function.

# %%
class InpaintingModel:
    '''
    Build UNET-like model for image inpainting task.
    '''
    def prepare_model(self, input_size=(256, 256, 3)):
        inputs = keras.layers.Input(input_size)

        conv1, pool1 = self.__ConvBlock(32, (3, 3), (2, 2), 'relu', 'same', inputs)
        conv2, pool2 = self.__ConvBlock(64, (3, 3), (2, 2), 'relu', 'same', pool1)
        conv3, pool3 = self.__ConvBlock(128, (3, 3), (2, 2), 'relu', 'same', pool2)
        conv4, pool4 = self.__ConvBlock(256, (3, 3), (2, 2), 'relu', 'same', pool3)

        conv5, up6 = self.__UpConvBlock(512, 256, (3, 3), (2, 2), (2, 2), 'relu', 'same', pool4, conv4)
        conv6, up7 = self.__UpConvBlock(256, 128, (3, 3), (2, 2), (2, 2), 'relu', 'same', up6, conv3)
        conv7, up8 = self.__UpConvBlock(128, 64, (3, 3), (2, 2), (2, 2), 'relu', 'same', up7, conv2)
        conv8, up9 = self.__UpConvBlock(64, 32, (3, 3), (2, 2), (2, 2), 'relu', 'same', up8, conv1)

        conv9 = self.__ConvBlock(32, (3, 3), (2, 2), 'relu', 'same', up9, False)

        outputs = keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(conv9)

        return keras.models.Model(inputs=[inputs], outputs=[outputs])

    def __ConvBlock(self, filters, kernel_size, pool_size, activation, padding, connecting_layer, pool_layer=True):
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(
            connecting_layer)
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(
            conv)
        if pool_layer:
            pool = keras.layers.MaxPooling2D(pool_size)(conv)
            return conv, pool
        else:
            return conv

    def __UpConvBlock(self, filters, up_filters, kernel_size, up_kernel, up_stride, activation, padding,
                      connecting_layer, shared_layer):
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(
            connecting_layer)
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(
            conv)
        up = keras.layers.Conv2DTranspose(filters=up_filters, kernel_size=up_kernel, strides=up_stride,
                                          padding=padding)(conv)
        up = keras.layers.concatenate([up, shared_layer], axis=3)

        return conv, up

# %%
keras.backend.clear_session()
model = InpaintingModel().prepare_model()
model.compile(optimizer='adam', loss='mse', metrics=[dice_coef])
# Out:
# 2023-05-29 07:10:37.003634: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.010022: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.010400: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.011477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.011797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.012097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.711355: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.711651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.711667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-29 07:10:37.711883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-29 07:10:37.711927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5875 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ## Train model

# %%
history = model.fit(traingen, 
          validation_data=testgen, 
          epochs=50, 
          steps_per_epoch=len(traingen), 
          validation_steps=len(testgen),
          use_multiprocessing=True)
# Out:
# Epoch 1/50
# 2023-05-29 07:10:42.097851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-29 07:10:46.414243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-29 07:10:51.088842: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x11f16a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-29 07:10:51.088886: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2023-05-29 07:10:51.111600: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-29 07:10:51.244710: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-05-29 07:10:52.067472: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.70GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:53.613171: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:53.640682: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:54.027121: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:54.027197: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:54.545227: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:54.545315: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:55.765329: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:55.765401: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-29 07:10:56.055734: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.59GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 63/63 [==============================] - ETA: 0s - loss: 0.0234 - dice_coef: 0.5551
# 2023-05-29 07:11:57.623831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 63/63 [==============================] - 84s 1s/step - loss: 0.0234 - dice_coef: 0.5551 - val_loss: 0.0049 - val_dice_coef: 0.5649
# Epoch 2/50
# 63/63 [==============================] - 91s 1s/step - loss: 0.0042 - dice_coef: 0.5866 - val_loss: 0.0033 - val_dice_coef: 0.5564
# Epoch 3/50
# 63/63 [==============================] - 92s 1s/step - loss: 0.0030 - dice_coef: 0.5902 - val_loss: 0.0026 - val_dice_coef: 0.5546
# Epoch 4/50
# 63/63 [==============================] - 92s 1s/step - loss: 0.0023 - dice_coef: 0.5916 - val_loss: 0.0021 - val_dice_coef: 0.5547
# Epoch 5/50
# 63/63 [==============================] - 97s 2s/step - loss: 0.0019 - dice_coef: 0.5930 - val_loss: 0.0018 - val_dice_coef: 0.5574
# Epoch 6/50
# 63/63 [==============================] - 88s 1s/step - loss: 0.0015 - dice_coef: 0.5933 - val_loss: 0.0015 - val_dice_coef: 0.5631
# Epoch 7/50
# 63/63 [==============================] - 93s 1s/step - loss: 0.0014 - dice_coef: 0.5939 - val_loss: 0.0016 - val_dice_coef: 0.5580
# Epoch 8/50
# 63/63 [==============================] - 96s 1s/step - loss: 0.0013 - dice_coef: 0.5940 - val_loss: 0.0013 - val_dice_coef: 0.5615
# Epoch 9/50
# 63/63 [==============================] - 90s 1s/step - loss: 0.0011 - dice_coef: 0.5950 - val_loss: 0.0011 - val_dice_coef: 0.5634
# Epoch 10/50
# 63/63 [==============================] - 94s 1s/step - loss: 0.0011 - dice_coef: 0.5946 - val_loss: 0.0011 - val_dice_coef: 0.5639
# Epoch 11/50
# 63/63 [==============================] - 92s 1s/step - loss: 9.9843e-04 - dice_coef: 0.5948 - val_loss: 0.0012 - val_dice_coef: 0.5649
# Epoch 12/50
# 63/63 [==============================] - 92s 1s/step - loss: 8.8637e-04 - dice_coef: 0.5947 - val_loss: 0.0010 - val_dice_coef: 0.5617
# Epoch 13/50
# 63/63 [==============================] - 92s 1s/step - loss: 8.9064e-04 - dice_coef: 0.5951 - val_loss: 0.0012 - val_dice_coef: 0.5591
# Epoch 14/50
# 63/63 [==============================] - 95s 1s/step - loss: 8.3932e-04 - dice_coef: 0.5950 - val_loss: 9.2381e-04 - val_dice_coef: 0.5654
# Epoch 15/50
# 63/63 [==============================] - 90s 1s/step - loss: 8.8430e-04 - dice_coef: 0.5951 - val_loss: 0.0014 - val_dice_coef: 0.5549
# Epoch 16/50
# 63/63 [==============================] - 93s 1s/step - loss: 7.9639e-04 - dice_coef: 0.5948 - val_loss: 8.4101e-04 - val_dice_coef: 0.5652
# Epoch 17/50
# 63/63 [==============================] - 93s 1s/step - loss: 7.7566e-04 - dice_coef: 0.5956 - val_loss: 9.0127e-04 - val_dice_coef: 0.5651
# Epoch 18/50
# 63/63 [==============================] - 79s 1s/step - loss: 6.9611e-04 - dice_coef: 0.5958 - val_loss: 7.5013e-04 - val_dice_coef: 0.5659
# Epoch 19/50
# 63/63 [==============================] - 95s 1s/step - loss: 6.9784e-04 - dice_coef: 0.5956 - val_loss: 7.0023e-04 - val_dice_coef: 0.5633
# Epoch 20/50
# 63/63 [==============================] - 92s 1s/step - loss: 7.2606e-04 - dice_coef: 0.5958 - val_loss: 8.8395e-04 - val_dice_coef: 0.5639
# Epoch 21/50
# 63/63 [==============================] - 89s 1s/step - loss: 6.8432e-04 - dice_coef: 0.5957 - val_loss: 7.7718e-04 - val_dice_coef: 0.5659
# Epoch 22/50
# 63/63 [==============================] - 86s 1s/step - loss: 6.4969e-04 - dice_coef: 0.5953 - val_loss: 8.5339e-04 - val_dice_coef: 0.5652
# Epoch 23/50
# 63/63 [==============================] - 94s 1s/step - loss: 8.2694e-04 - dice_coef: 0.5952 - val_loss: 8.8558e-04 - val_dice_coef: 0.5635
# Epoch 24/50
# 63/63 [==============================] - 91s 1s/step - loss: 6.3078e-04 - dice_coef: 0.5961 - val_loss: 6.9091e-04 - val_dice_coef: 0.5662
# Epoch 25/50
# 63/63 [==============================] - 94s 1s/step - loss: 5.9642e-04 - dice_coef: 0.5959 - val_loss: 6.5565e-04 - val_dice_coef: 0.5649
# Epoch 26/50
# 63/63 [==============================] - 94s 1s/step - loss: 6.5748e-04 - dice_coef: 0.5960 - val_loss: 7.4815e-04 - val_dice_coef: 0.5657
# Epoch 27/50
# 63/63 [==============================] - 85s 1s/step - loss: 6.3376e-04 - dice_coef: 0.5962 - val_loss: 8.1523e-04 - val_dice_coef: 0.5658
# Epoch 28/50
# 63/63 [==============================] - 91s 1s/step - loss: 6.0736e-04 - dice_coef: 0.5963 - val_loss: 7.3126e-04 - val_dice_coef: 0.5669
# Epoch 29/50
# 63/63 [==============================] - 91s 1s/step - loss: 7.6511e-04 - dice_coef: 0.5952 - val_loss: 7.7122e-04 - val_dice_coef: 0.5696
# Epoch 30/50
# 63/63 [==============================] - 92s 1s/step - loss: 6.3093e-04 - dice_coef: 0.5956 - val_loss: 6.5422e-04 - val_dice_coef: 0.5660
# Epoch 31/50
# 63/63 [==============================] - 89s 1s/step - loss: 5.7586e-04 - dice_coef: 0.5960 - val_loss: 6.7475e-04 - val_dice_coef: 0.5640
# Epoch 32/50
# 63/63 [==============================] - 92s 1s/step - loss: 5.8130e-04 - dice_coef: 0.5957 - val_loss: 6.4230e-04 - val_dice_coef: 0.5682
# Epoch 33/50
# 63/63 [==============================] - 92s 1s/step - loss: 5.9327e-04 - dice_coef: 0.5953 - val_loss: 6.7645e-04 - val_dice_coef: 0.5617
# Epoch 34/50
# 63/63 [==============================] - 91s 1s/step - loss: 6.1464e-04 - dice_coef: 0.5957 - val_loss: 7.5344e-04 - val_dice_coef: 0.5628
# Epoch 35/50
# 63/63 [==============================] - 94s 1s/step - loss: 5.5969e-04 - dice_coef: 0.5961 - val_loss: 7.4686e-04 - val_dice_coef: 0.5691
# Epoch 36/50
# 63/63 [==============================] - 90s 1s/step - loss: 5.7927e-04 - dice_coef: 0.5956 - val_loss: 5.7356e-04 - val_dice_coef: 0.5693
# Epoch 37/50
# 63/63 [==============================] - 96s 1s/step - loss: 5.9171e-04 - dice_coef: 0.5959 - val_loss: 6.2476e-04 - val_dice_coef: 0.5676
# Epoch 38/50
# 63/63 [==============================] - 89s 1s/step - loss: 5.9033e-04 - dice_coef: 0.5959 - val_loss: 7.7462e-04 - val_dice_coef: 0.5657
# Epoch 39/50
# 63/63 [==============================] - 94s 1s/step - loss: 5.6958e-04 - dice_coef: 0.5963 - val_loss: 8.6389e-04 - val_dice_coef: 0.5602
# Epoch 40/50
# 63/63 [==============================] - 88s 1s/step - loss: 6.6453e-04 - dice_coef: 0.5952 - val_loss: 5.1022e-04 - val_dice_coef: 0.5645
# Epoch 41/50
# 63/63 [==============================] - 95s 1s/step - loss: 5.2827e-04 - dice_coef: 0.5955 - val_loss: 6.8366e-04 - val_dice_coef: 0.5653
# Epoch 42/50
# 63/63 [==============================] - 87s 1s/step - loss: 5.1932e-04 - dice_coef: 0.5964 - val_loss: 6.9312e-04 - val_dice_coef: 0.5681
# Epoch 43/50
# 63/63 [==============================] - 93s 1s/step - loss: 5.2815e-04 - dice_coef: 0.5962 - val_loss: 7.4911e-04 - val_dice_coef: 0.5666
# Epoch 44/50
# 63/63 [==============================] - 95s 1s/step - loss: 5.5443e-04 - dice_coef: 0.5961 - val_loss: 6.3549e-04 - val_dice_coef: 0.5638
# Epoch 45/50
# 63/63 [==============================] - 91s 1s/step - loss: 5.0472e-04 - dice_coef: 0.5965 - val_loss: 6.4243e-04 - val_dice_coef: 0.5637
# Epoch 46/50
# 63/63 [==============================] - 94s 1s/step - loss: 7.2106e-04 - dice_coef: 0.5952 - val_loss: 0.0011 - val_dice_coef: 0.5731
# Epoch 47/50
# 63/63 [==============================] - 92s 1s/step - loss: 5.9718e-04 - dice_coef: 0.5960 - val_loss: 7.1191e-04 - val_dice_coef: 0.5657
# Epoch 48/50
# 63/63 [==============================] - 94s 1s/step - loss: 5.1520e-04 - dice_coef: 0.5961 - val_loss: 6.1480e-04 - val_dice_coef: 0.5634
# Epoch 49/50
# 63/63 [==============================] - 96s 1s/step - loss: 5.8971e-04 - dice_coef: 0.5960 - val_loss: 6.1655e-04 - val_dice_coef: 0.5650
# Epoch 50/50
# 63/63 [==============================] - 99s 2s/step - loss: 5.0403e-04 - dice_coef: 0.5962 - val_loss: 6.9062e-04 - val_dice_coef: 0.5660

# %% [markdown]
# ## Save Model and Training history

# %%
with open('AE_model_256.pkl','wb') as output:
    pickle.dump(model,output)

# %%
with open('AE_model_hist_256.pkl', 'wb') as output:
    pickle.dump(history, output)

# %% [markdown]
# ## Inpaint Images and Display Output

# %%
## Examples
rows = 32
sample_idx = 2
sample_images, sample_labels = traingen[sample_idx]

fig, axs = plt.subplots(nrows=rows, ncols=3, figsize=(6, 2*rows))

for i in range(32):
    impainted_image = model.predict(sample_images[i].reshape((1,)+sample_images[i].shape))
    axs[i][0].imshow(sample_labels[i])
    axs[i][1].imshow(sample_images[i])
    axs[i][2].imshow(impainted_image.reshape(impainted_image.shape[1:]))

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
